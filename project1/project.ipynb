# %%
import random
import time
import pandas as pd
import numpy as np
import sys

from data_8000 import reverse8

input1 = reverse8.copy()

# Increase the recursion limit
sys.setrecursionlimit(10000)

# %%
# Bubble sort algorithm (most efficient version)
def bubble_sort(arr):
    n = len(arr)
    comparisons = 0
    while n > 1:
        new_n = 0
        for i in range(1, n):
            comparisons += 1
            if arr[i - 1] > arr[i]:
                arr[i - 1], arr[i] = arr[i], arr[i - 1]
                new_n = i
        n = new_n
    return comparisons

# %%
# Insersion sort algorithm
def insertion_sort(arr):
    comparisons = 0
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            comparisons += 1
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
        if j >= 0:
            comparisons += 1
    return comparisons

# %%
# Quick sort algorithm with randomized pivot selection
class Quick_Sort_Randomized:
    def sort(self, arr):
        global comparisons
        comparisons = 0
        self.quick_sort_recursive(arr, 0, len(arr) - 1)
        return comparisons

    def partition(self, arr, low, high):
        global comparisons
        pivot = arr[high]
        i = low - 1
        for j in range(low, high):
            comparisons += 1
            if arr[j] <= pivot:
                i += 1
                arr[i], arr[j] = arr[j], arr[i]
        arr[i + 1], arr[high] = arr[high], arr[i + 1]
        return i + 1

    def quick_sort_recursive(self, arr, low, high):
        if low > high:
            return
        pi = self.partition(arr, low, high)
        self.quick_sort_recursive(arr, low, pi - 1)
        self.quick_sort_recursive(arr, pi + 1, high)

quick_sort_randomized = Quick_Sort_Randomized()

print(quick_sort_randomized.sort(input1.copy()))
# Out:
# 31837190

# %%
# Quick sort algorithm with median-of-three pivot selection
class Quick_Sort_Median:
    def sort(self, arr):
        global comparisons
        comparisons = 0
        self.quick_sort_recursive(arr, 0, len(arr) - 1)
        return comparisons

    def median_of_three(self, arr, low, high):
        global comparisons
        mid = (low + high) // 2
        if arr[low] > arr[mid]:
            arr[low], arr[mid] = arr[mid], arr[low]
        if arr[low] > arr[high]:
            arr[low], arr[high] = arr[high], arr[low]
        if arr[mid] > arr[high]:
            arr[mid], arr[high] = arr[high], arr[mid]
        comparisons += 3
        return mid

    def partition(self, arr, low, high):
        global comparisons
        pivot_index = self.median_of_three(arr, low, high)
        pivot = arr[pivot_index]
        arr[pivot_index], arr[high] = arr[high], arr[pivot_index]
        i = low - 1
        for j in range(low, high):
            comparisons += 1
            if arr[j] < pivot:
                i += 1
                arr[i], arr[j] = arr[j], arr[i]
        arr[i + 1], arr[high] = arr[high], arr[i + 1]
        return i + 1

    def quick_sort_recursive(self, arr, low, high):
        if low > high:
            return
        pi = self.partition(arr, low, high)
        self.quick_sort_recursive(arr, low, pi - 1)
        self.quick_sort_recursive(arr, pi + 1, high)

quick_sort_median = Quick_Sort_Median()

print(quick_sort_median.sort(input1.copy()))
# Out:
# 193803

# %%
# Heap sort algorithm
def heapify(arr, n, i):
    if i > n:
        return
    global comparisons
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2
    # Compare left child
    if left < n:
        comparisons += 1
        if arr[left] > arr[largest]:
            largest = left
    # Compare right child
    if right < n:
        comparisons += 1
        if arr[right] > arr[largest]:
            largest = right
    # If largest is not root
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)

def heap_sort(arr):
    global comparisons
    comparisons = 0
    n = len(arr)
    # Build a maxheap
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
    # Extract elements one by one
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)
    return comparisons

print(heap_sort(input1.copy()))
# Out:
# 176067

# %%
# Merge sort algorithm
class Merge_Sort:
    def sort(self, arr):
        self.comparisons = 0
        arr = self.recursive(arr)
        return self.comparisons

    def merge(self, left, right):
        merged = []
        i = j = 0
        while i < len(left) and j < len(right):
            self.comparisons += 1
            if left[i] < right[j]:
                merged.append(left[i])
                i += 1
            else:
                merged.append(right[j])
                j += 1
        merged.extend(left[i:])
        merged.extend(right[j:])
        return merged

    def recursive(self, arr):
        if len(arr) <= 1:
            return arr
        if len(arr) == 2:
            self.comparisons += 1
            if arr[0] > arr[1]:
                return [arr[1], arr[0]]
            return arr
        mid1 = len(arr) // 3
        mid2 = 2*len(arr) // 3

        left = self.recursive(arr[:mid1])
        mid = self.recursive(arr[mid1:mid2])
        right = self.recursive(arr[mid2:])
        return self.merge(self.merge(left, mid), right)

merge_sort = Merge_Sort()

print(merge_sort.sort(input1.copy()))
# Out:
# 45107

# %%
class List:
    def __init__(self, type, size, list):
        self.type = type
        self.size = size
        self.list = list

input_data = []

for i in [1000, 2000, 4000, 8000]:
    input_data.append(List("Random", i, [random.randint(1, 1000001) for _ in range(i)]))
length = len(input_data)
for i in range(length):
    input_data.append(List("Sorted", input_data[i].size, sorted(input_data[i].list)))
for i in range(length):
    input_data.append(List("Reversed", input_data[i].size, sorted(input_data[i].list, reverse=True)))

# Extract the three 8000-element datasets
datasets_8000 = [data for data in input_data if data.size == 8000]

# Write the datasets into a .txt file
with open('datasets_8000.txt', 'w') as file:
    for dataset in datasets_8000:
        file.write(f"{dataset.type}:\n")
        file.write(','.join(map(str, dataset.list)) + "\n\n")

# %%
dict = {
    'b': {'label': 'Bubble Sort', 'function': bubble_sort},
    'i': {'label': 'Insertion Sort', 'function': insertion_sort},
    'qr': {'label': 'Quick Sort Randomized', 'function': quick_sort_randomized.sort},
    'qm': {'label': 'Quick Sort Median', 'function': quick_sort_median.sort},
    'h': {'label': 'Heap Sort', 'function': heap_sort},
    'm': {'label': '3-Way Merge Sort', 'function': merge_sort.sort},
}

sort_algo, results = ['b', 'i', 'qr', 'qm', 'h', 'm'], []

print('{:>2}.  {:^9}  {:^9} {:^24} {:>12}  {:>16}'.format("No", "Data Type", "Data Size", "Sorting Algorithm", "Elapsed time", "No. Comparisons"))
for s in sort_algo:
    if s not in dict:
        continue
    for data in input_data :
        input = data.list.copy()
        start_time = time.time()
        comparisons = dict[s]['function'](input)
        duration = time.time() - start_time
        line_new = '{:>2}.  {:^9}  {:^9} {:^24} {:>12}  {:>16,}'.format(len(results)+1, data.type, data.size, dict[s]['label'], f'{duration*1000:,.3f} ms', comparisons)
        print(line_new)
        results.append([dict[s]['label'], data.type, len(input), duration * 1000, int(comparisons)])
# Out:
# No.  Data Type  Data Size    Sorting Algorithm     Elapsed time   No. Comparisons
#  1.   Random      1000          Bubble Sort          120.545 ms           493,561
#  2.   Random      2000          Bubble Sort          216.212 ms         1,993,103
#  3.   Random      4000          Bubble Sort          832.459 ms         7,994,044
#  4.   Random      8000          Bubble Sort        3,287.951 ms        31,968,701
#  5.   Sorted      1000          Bubble Sort            0.060 ms               999
#  6.   Sorted      2000          Bubble Sort            0.123 ms             1,999
#  7.   Sorted      4000          Bubble Sort            0.245 ms             3,999
#  8.   Sorted      8000          Bubble Sort            0.492 ms             7,999
#  9.  Reversed     1000          Bubble Sort           60.738 ms           499,500
# 10.  Reversed     2000          Bubble Sort          255.018 ms         1,999,000
# 11.  Reversed     4000          Bubble Sort        1,064.565 ms         7,998,000
# 12.  Reversed     8000          Bubble Sort        4,372.442 ms        31,996,000
# 13.   Random      1000         Insertion Sort         23.826 ms           252,167
# 14.   Random      2000         Insertion Sort         93.053 ms         1,011,073
# 15.   Random      4000         Insertion Sort        379.304 ms         4,009,109
# 16.   Random      8000         Insertion Sort      1,504.560 ms        15,868,141
# 17.   Sorted      1000         Insertion Sort          0.119 ms               999
# 18.   Sorted      2000         Insertion Sort          0.241 ms             1,999
# 19.   Sorted      4000         Insertion Sort          0.486 ms             3,999
# 20.   Sorted      8000         Insertion Sort          0.975 ms             7,999
# 21.  Reversed     1000         Insertion Sort         44.680 ms           499,500
# 22.  Reversed     2000         Insertion Sort        186.495 ms         1,999,000
# 23.  Reversed     4000         Insertion Sort        753.481 ms         7,998,000
# 24.  Reversed     8000         Insertion Sort      3,036.464 ms        31,996,000
# 25.   Random      1000     Quick Sort Randomized       1.435 ms            10,755
# 26.   Random      2000     Quick Sort Randomized       3.073 ms            24,010
# 27.   Random      4000     Quick Sort Randomized       6.873 ms            54,425
# 28.   Random      8000     Quick Sort Randomized      14.897 ms           119,426
# 29.   Sorted      1000     Quick Sort Randomized      56.908 ms           499,500
# 30.   Sorted      2000     Quick Sort Randomized     228.785 ms         1,999,000
# 31.   Sorted      4000     Quick Sort Randomized     947.322 ms         7,998,000
# 32.   Sorted      8000     Quick Sort Randomized   3,800.790 ms        31,996,000
# 33.  Reversed     1000     Quick Sort Randomized      44.111 ms           499,500
# 34.  Reversed     2000     Quick Sort Randomized     183.819 ms         1,997,958
# 35.  Reversed     4000     Quick Sort Randomized     742.959 ms         7,993,346
# 36.  Reversed     8000     Quick Sort Randomized   2,946.965 ms        31,899,678
# 37.   Random      1000       Quick Sort Median         1.838 ms            12,360
# 38.   Random      2000       Quick Sort Median         3.503 ms            27,117
# 39.   Random      4000       Quick Sort Median         7.240 ms            57,745
# 40.   Random      8000       Quick Sort Median        15.286 ms           126,825
# 41.   Sorted      1000       Quick Sort Median         1.375 ms            10,987
# 42.   Sorted      2000       Quick Sort Median         2.975 ms            23,965
# 43.   Sorted      4000       Quick Sort Median         6.391 ms            51,920
# 44.   Sorted      8000       Quick Sort Median        14.021 ms           111,828
# 45.  Reversed     1000       Quick Sort Median         1.996 ms            17,205
# 46.  Reversed     2000       Quick Sort Median         4.424 ms            38,880
# 47.  Reversed     4000       Quick Sort Median        10.018 ms            87,378
# 48.  Reversed     8000       Quick Sort Median        21.725 ms           193,758
# 49.   Random      1000           Heap Sort             3.100 ms            16,890
# 50.   Random      2000           Heap Sort             7.026 ms            37,669
# 51.   Random      4000           Heap Sort            15.524 ms            83,479
# 52.   Random      8000           Heap Sort            33.278 ms           182,898
# 53.   Sorted      1000           Heap Sort             3.329 ms            17,583
# 54.   Sorted      2000           Heap Sort             6.883 ms            39,161
# 55.   Sorted      4000           Heap Sort            15.260 ms            86,576
# 56.   Sorted      8000           Heap Sort            34.664 ms           189,426
# 57.  Reversed     1000           Heap Sort             2.721 ms            15,965
# 58.  Reversed     2000           Heap Sort             6.304 ms            35,964
# 59.  Reversed     4000           Heap Sort            14.290 ms            80,151
# 60.  Reversed     8000           Heap Sort            32.297 ms           176,073
# 61.   Random      1000        3-Way Merge Sort         2.403 ms             9,044
# 62.   Random      2000        3-Way Merge Sort         4.980 ms            20,207
# 63.   Random      4000        3-Way Merge Sort        10.082 ms            44,617
# 64.   Random      8000        3-Way Merge Sort        21.247 ms            97,644
# 65.   Sorted      1000        3-Way Merge Sort         1.408 ms             5,970
# 66.   Sorted      2000        3-Way Merge Sort         3.258 ms            13,540
# 67.   Sorted      4000        3-Way Merge Sort         7.092 ms            29,084
# 68.   Sorted      8000        3-Way Merge Sort        14.670 ms            63,213
# 69.  Reversed     1000        3-Way Merge Sort         1.145 ms             4,381
# 70.  Reversed     2000        3-Way Merge Sort         2.780 ms             9,433
# 71.  Reversed     4000        3-Way Merge Sort         4.832 ms            20,898
# 72.  Reversed     8000        3-Way Merge Sort        12.453 ms            45,107

# %%
# Define column names of the data frame
columns = ['Sort Algorithm', 'Input Type', 'Input Size', 'Runtime (ms)', 'Number of Comparisons']

# Create a dataframe
df_original = pd.DataFrame(results, columns=columns)

df = df_original.copy()

# Format the columns to display decimal digits and add thousands separators
df['Input Size'] = df['Input Size'].apply(lambda x: f'{int(x):,}')
df['Number of Comparisons'] = df['Number of Comparisons'].apply(lambda x: f'{int(x):,}')
df['Runtime (ms)'] = df['Runtime (ms)'].apply(lambda x: f'{x:,.3f}')

# Pivot the dataframe to have 'Sort Algorithm' as columns
df = df.pivot(index=['Input Type', 'Input Size'], columns='Sort Algorithm', values=['Runtime (ms)', 'Number of Comparisons'])

# Reorder the columns
order = ['Bubble Sort', 'Insertion Sort', 'Quick Sort Randomized', 'Quick Sort Median', 'Heap Sort', '3-Way Merge Sort']
df = df.reindex(columns=pd.MultiIndex.from_product([['Runtime (ms)', 'Number of Comparisons'], order]))

input_type_order = ['Random', 'Sorted', 'Reversed']
df = df.reindex(input_type_order, level='Input Type')

# Save the dataframe to a CSV and xlsx file
df.to_csv('sort_algorithms.csv')
df.to_excel('sort_algorithms.xlsx')
markdown_table = df.to_markdown(index=False)

df
# Out:
#                       Runtime (ms)                                       \
#                        Bubble Sort Insertion Sort Quick Sort Randomized
# Input Type Input Size
# Random     1,000           120.545         23.826                 1.435
#            2,000           216.212         93.053                 3.073
#            4,000           832.459        379.304                 6.873
#            8,000         3,287.951      1,504.560                14.897
# Sorted     1,000             0.060          0.119                56.908
#            2,000             0.123          0.241               228.785
#            4,000             0.245          0.486               947.322
#            8,000             0.492          0.975             3,800.790
# Reversed   1,000            60.738         44.680                44.111
#            2,000           255.018        186.495               183.819
#            4,000         1,064.565        753.481               742.959
#            8,000         4,372.442      3,036.464             2,946.965
#
#                                                                     \
#                       Quick Sort Median Heap Sort 3-Way Merge Sort
# Input Type Input Size
# Random     1,000                  1.838     3.100            2.403
#            2,000                  3.503     7.026            4.980
#            4,000                  7.240    15.524           10.082
#            8,000                 15.286    33.278           21.247
# Sorted     1,000                  1.375     3.329            1.408
#            2,000                  2.975     6.883            3.258
#            4,000                  6.391    15.260            7.092
#            8,000                 14.021    34.664           14.670
# Reversed   1,000                  1.996     2.721            1.145
#            2,000                  4.424     6.304            2.780
#            4,000                 10.018    14.290            4.832
#            8,000                 21.725    32.297           12.453
#
#                       Number of Comparisons                 \
#                                 Bubble Sort Insertion Sort
# Input Type Input Size
# Random     1,000                    493,561        252,167
#            2,000                  1,993,103      1,011,073
#            4,000                  7,994,044      4,009,109
#            8,000                 31,968,701     15,868,141
# Sorted     1,000                        999            999
#            2,000                      1,999          1,999
#            4,000                      3,999          3,999
#            8,000                      7,999          7,999
# Reversed   1,000                    499,500        499,500
#            2,000                  1,999,000      1,999,000
#            4,000                  7,998,000      7,998,000
#            8,000                 31,996,000     31,996,000
#
#                                                                          \
#                       Quick Sort Randomized Quick Sort Median Heap Sort
# Input Type Input Size
# Random     1,000                     10,755            12,360    16,890
#            2,000                     24,010            27,117    37,669
#            4,000                     54,425            57,745    83,479
#            8,000                    119,426           126,825   182,898
# Sorted     1,000                    499,500            10,987    17,583
#            2,000                  1,999,000            23,965    39,161
#            4,000                  7,998,000            51,920    86,576
#            8,000                 31,996,000           111,828   189,426
# Reversed   1,000                    499,500            17,205    15,965
#            2,000                  1,997,958            38,880    35,964
#            4,000                  7,993,346            87,378    80,151
#            8,000                 31,899,678           193,758   176,073
#
#
#                       3-Way Merge Sort
# Input Type Input Size
# Random     1,000                 9,044
#            2,000                20,207
#            4,000                44,617
#            8,000                97,644
# Sorted     1,000                 5,970
#            2,000                13,540
#            4,000                29,084
#            8,000                63,213
# Reversed   1,000                 4,381
#            2,000                 9,433
#            4,000                20,898
#            8,000                45,107

# %%
markdown_table = df_original.to_markdown(index=False)
print(markdown_table)
# Out:
# | Sort Algorithm        | Input Type   |   Input Size |   Runtime (ms) |   Number of Comparisons |
# |:----------------------|:-------------|-------------:|---------------:|------------------------:|
# | Bubble Sort           | Random       |         1000 |    120.545     |                  493561 |
# | Bubble Sort           | Random       |         2000 |    216.212     |                 1993103 |
# | Bubble Sort           | Random       |         4000 |    832.459     |                 7994044 |
# | Bubble Sort           | Random       |         8000 |   3287.95      |                31968701 |
# | Bubble Sort           | Sorted       |         1000 |      0.0600815 |                     999 |
# | Bubble Sort           | Sorted       |         2000 |      0.122786  |                    1999 |
# | Bubble Sort           | Sorted       |         4000 |      0.244856  |                    3999 |
# | Bubble Sort           | Sorted       |         8000 |      0.491858  |                    7999 |
# | Bubble Sort           | Reversed     |         1000 |     60.7381    |                  499500 |
# | Bubble Sort           | Reversed     |         2000 |    255.018     |                 1999000 |
# | Bubble Sort           | Reversed     |         4000 |   1064.56      |                 7998000 |
# | Bubble Sort           | Reversed     |         8000 |   4372.44      |                31996000 |
# | Insertion Sort        | Random       |         1000 |     23.8259    |                  252167 |
# | Insertion Sort        | Random       |         2000 |     93.0531    |                 1011073 |
# | Insertion Sort        | Random       |         4000 |    379.304     |                 4009109 |
# | Insertion Sort        | Random       |         8000 |   1504.56      |                15868141 |
# | Insertion Sort        | Sorted       |         1000 |      0.118971  |                     999 |
# | Insertion Sort        | Sorted       |         2000 |      0.240803  |                    1999 |
# | Insertion Sort        | Sorted       |         4000 |      0.486135  |                    3999 |
# | Insertion Sort        | Sorted       |         8000 |      0.974894  |                    7999 |
# | Insertion Sort        | Reversed     |         1000 |     44.6799    |                  499500 |
# | Insertion Sort        | Reversed     |         2000 |    186.495     |                 1999000 |
# | Insertion Sort        | Reversed     |         4000 |    753.481     |                 7998000 |
# | Insertion Sort        | Reversed     |         8000 |   3036.46      |                31996000 |
# | Quick Sort Randomized | Random       |         1000 |      1.4348    |                   10755 |
# | Quick Sort Randomized | Random       |         2000 |      3.07298   |                   24010 |
# | Quick Sort Randomized | Random       |         4000 |      6.87289   |                   54425 |
# | Quick Sort Randomized | Random       |         8000 |     14.8973    |                  119426 |
# | Quick Sort Randomized | Sorted       |         1000 |     56.9081    |                  499500 |
# | Quick Sort Randomized | Sorted       |         2000 |    228.785     |                 1999000 |
# | Quick Sort Randomized | Sorted       |         4000 |    947.322     |                 7998000 |
# | Quick Sort Randomized | Sorted       |         8000 |   3800.79      |                31996000 |
# | Quick Sort Randomized | Reversed     |         1000 |     44.111     |                  499500 |
# | Quick Sort Randomized | Reversed     |         2000 |    183.819     |                 1997958 |
# | Quick Sort Randomized | Reversed     |         4000 |    742.959     |                 7993346 |
# | Quick Sort Randomized | Reversed     |         8000 |   2946.96      |                31899678 |
# | Quick Sort Median     | Random       |         1000 |      1.83797   |                   12360 |
# | Quick Sort Median     | Random       |         2000 |      3.50285   |                   27117 |
# | Quick Sort Median     | Random       |         4000 |      7.24006   |                   57745 |
# | Quick Sort Median     | Random       |         8000 |     15.2862    |                  126825 |
# | Quick Sort Median     | Sorted       |         1000 |      1.37496   |                   10987 |
# | Quick Sort Median     | Sorted       |         2000 |      2.97523   |                   23965 |
# | Quick Sort Median     | Sorted       |         4000 |      6.39105   |                   51920 |
# | Quick Sort Median     | Sorted       |         8000 |     14.0209    |                  111828 |
# | Quick Sort Median     | Reversed     |         1000 |      1.99604   |                   17205 |
# | Quick Sort Median     | Reversed     |         2000 |      4.4241    |                   38880 |
# | Quick Sort Median     | Reversed     |         4000 |     10.0179    |                   87378 |
# | Quick Sort Median     | Reversed     |         8000 |     21.7252    |                  193758 |
# | Heap Sort             | Random       |         1000 |      3.10016   |                   16890 |
# | Heap Sort             | Random       |         2000 |      7.0262    |                   37669 |
# | Heap Sort             | Random       |         4000 |     15.5237    |                   83479 |
# | Heap Sort             | Random       |         8000 |     33.278     |                  182898 |
# | Heap Sort             | Sorted       |         1000 |      3.32904   |                   17583 |
# | Heap Sort             | Sorted       |         2000 |      6.88291   |                   39161 |
# | Heap Sort             | Sorted       |         4000 |     15.26      |                   86576 |
# | Heap Sort             | Sorted       |         8000 |     34.6642    |                  189426 |
# | Heap Sort             | Reversed     |         1000 |      2.72107   |                   15965 |
# | Heap Sort             | Reversed     |         2000 |      6.30379   |                   35964 |
# | Heap Sort             | Reversed     |         4000 |     14.2899    |                   80151 |
# | Heap Sort             | Reversed     |         8000 |     32.2969    |                  176073 |
# | 3-Way Merge Sort      | Random       |         1000 |      2.40278   |                    9044 |
# | 3-Way Merge Sort      | Random       |         2000 |      4.98009   |                   20207 |
# | 3-Way Merge Sort      | Random       |         4000 |     10.0818    |                   44617 |
# | 3-Way Merge Sort      | Random       |         8000 |     21.2469    |                   97644 |
# | 3-Way Merge Sort      | Sorted       |         1000 |      1.40786   |                    5970 |
# | 3-Way Merge Sort      | Sorted       |         2000 |      3.25799   |                   13540 |
# | 3-Way Merge Sort      | Sorted       |         4000 |      7.092     |                   29084 |
# | 3-Way Merge Sort      | Sorted       |         8000 |     14.6701    |                   63213 |
# | 3-Way Merge Sort      | Reversed     |         1000 |      1.14512   |                    4381 |
# | 3-Way Merge Sort      | Reversed     |         2000 |      2.77972   |                    9433 |
# | 3-Way Merge Sort      | Reversed     |         4000 |      4.83203   |                   20898 |
# | 3-Way Merge Sort      | Reversed     |         8000 |     12.4528    |                   45107 |
